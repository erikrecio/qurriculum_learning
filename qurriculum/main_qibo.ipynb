# %%
import numpy as np
import qibo
from qibo.symbols import X, Z, I
from qibo import models, gates, hamiltonians

import cma
from scipy.optimize import minimize
from shapely.geometry import Polygon, Point

qibo.set_backend("numpy")
# Out:
# [Qibo 0.1.11|INFO|2023-12-20 22:26:20]: Using numpy backend on /CPU:0

# %%
num_data = 15   # How many ground states do we want for training?
nqubits = 2     # num qubits
accuracy_training = 100 # Maximum acc percentage

layers = int(np.log2(nqubits))
nparams = 30*(layers-1) + 15

# %% [markdown]
# # Gound states

# %%
def ground_state(j1, j2):
    
    symbolic_expr = 0
    for i in range(nqubits):
        symbolic_expr += Z(i)
        symbolic_expr -= j1*X(i)*X((i+1)%nqubits)
        symbolic_expr -= j2*X(i)*Z((i+1)%nqubits)*X((i+2)%nqubits)
    
    hamiltonian = hamiltonians.SymbolicHamiltonian(form=symbolic_expr)
    ground_state = hamiltonian.ground_state()
    
    return ground_state

# %%
def labeling(x, y):
    # Definir las coordenadas de los puntos de cada región
    region1_coords = [(-2, 1), (2, 1), (0, -1)]
    region2_coords = [(0, -1), (3, -4), (4, -4), (4, 3)]
    region3_coords = [(0, -1), (-3, -4), (-4, -4), (-4, 3)]
    region4_coords = [(-2, 1), (2, 1), (4, 3), (4, 4), (-4, 4), (-4, 3)]
    region5_coords = [(-3, -4), (0, -1), (3, -4)]
    
    # Crear objetos Polygon para cada región
    region1_poly = Polygon(region1_coords)
    region2_poly = Polygon(region2_coords)
    region3_poly = Polygon(region3_coords)
    region4_poly = Polygon(region4_coords)
    region5_poly = Polygon(region5_coords)
    
    punto = Point(x, y)
    if region1_poly.contains(punto):
        return 3
    elif region2_poly.contains(punto):
        return 1
    elif region3_poly.contains(punto):
        return 2
    elif region4_poly.contains(punto):
        return 0
    elif region5_poly.contains(punto):
        return 0
    else:
        return None # Si el punto no está en ninguna región

# %%
gs_list = []
label_list = []
j1_list = np.random.uniform(-4, 4, num_data)
j2_list = np.random.uniform(-4, 4, num_data)

for i in range(num_data):
    gs_list.append(ground_state(j1_list[i], j2_list[i]))
    label_list.append(labeling(j1_list[i], j2_list[i]))
# Out:
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.
# [Qibo 0.2.3|WARNING|2023-12-20 09:57:53]: Calculating the dense form of a symbolic Hamiltonian. This operation is memory inefficient.

# %%
gs_list = np.array(gs_list)
print(gs_list.shape)
# Out:
# (15, 4)

# %% [markdown]
# # CNN

# %%
def convolutional_layer(c, q1, q2, param):
    c.add(gates.U3(q1, theta=param[0], phi=param[1], lam=param[2]))
    c.add(gates.U3(q1, theta=param[3], phi=param[4], lam=param[5]))
    c.add(gates.CNOT(q2, q1))
    c.add(gates.RZ(q1, theta=param[6]))
    c.add(gates.RY(q2, theta=param[7]))
    c.add(gates.CNOT(q1, q2))
    c.add(gates.RY(q2, theta=param[8]))
    c.add(gates.CNOT(q2, q1))
    c.add(gates.U3(q1, theta=param[9], phi=param[10], lam=param[11]))
    c.add(gates.U3(q1, theta=param[12], phi=param[13], lam=param[14]))
    return c

def pooling_layer(c, q1, q2, param):
    c.add(gates.U3(q1, theta=param[0], phi=param[1], lam=param[2]))
    c.add(gates.U3(q1, theta=param[3], phi=param[4], lam=param[5]))
    c.add(gates.CNOT(q2, q1))
    c.add(gates.RZ(q1, theta=param[6]))
    c.add(gates.RY(q2, theta=param[7]))
    c.add(gates.CNOT(q1, q2))
    c.add(gates.RY(q2, theta=param[8]))
    c.add(gates.CNOT(q2, q1))
    c.add(gates.U3(q1, theta=param[9], phi=param[10], lam=param[11]))
    c.add(gates.U3(q1, theta=param[12], phi=param[13], lam=param[14]))
    return c

# %%
def cnn(params):
    
    circuit = models.Circuit(nqubits)
    qubits = list(range(nqubits))
    
    for j in range(layers-1):
        
        len_qubits = len(qubits)
        
        for i in range(len_qubits//2):
            convolutional_layer(circuit, qubits[2*i], qubits[(2*i+1)%len_qubits], params[15*2*j:15*(2*j+1)])
        
        for i in range(len_qubits//2):
            convolutional_layer(circuit, qubits[2*i+1], qubits[(2*i+2)%len_qubits], params[15*2*j:15*(2*j+1)])
            
        for i in range(len_qubits//2):
            pooling_layer(circuit, qubits[2*i], qubits[(2*i+1)%len_qubits], params[15*(2*j+1):15*(2*j+2)])

        qub = []
        for i in range(len_qubits):
            if i%2 == 1:
                qub.append(qubits[i])
                
        qubits = qub
    
    convolutional_layer(circuit, qubits[0], qubits[1], params[15*(2*layers-2):15*(2*layers-1)])

    return circuit

# %%
params = np.random.uniform(0, 2*np.pi, nparams)
c = cnn(params)
print(c.draw())
# Out:
# q0: ─U3─U3─X─RZ─o────X─U3─U3─
# q1: ───────o─RY─X─RY─o───────

# %% [markdown]
# # Loss and accuracy

# %%
ham7 = hamiltonians.SymbolicHamiltonian(form=Z(nqubits-1))
ham3 = hamiltonians.SymbolicHamiltonian(form=Z(nqubits//2-1)*I(nqubits-1))
ham37 = hamiltonians.SymbolicHamiltonian(form=Z(nqubits//2-1)*Z(nqubits-1))

# %%
def loss(params):
    cost = 0
    circuit = cnn(params)
    
    for j in range(num_data):
        final_state = circuit(gs_list[j]).state()

        z3 = np.real(ham3.expectation(final_state))
        z7 = np.real(ham7.expectation(final_state))
        zz37 = np.real(ham37.expectation(final_state))
        
        proj_00 = (1+zz37+z3+z7)/4
        proj_01 = (1-zz37-z3+z7)/4
        proj_10 = (1-zz37+z3-z7)/4
        proj_11 = (1+zz37-z3-z7)/4
        
        if label_list[j] == 0:
            cost += proj_00
        elif label_list[j] == 1:
            cost += proj_01
        elif label_list[j] == 2:
            cost += proj_10
        else:
            cost += proj_11

        # adding extra terms to equalize incorrect classes might help in the optimization, 
        # although it is not required
        """
        if label_list[j] == 0:
            cost += proj_00 + ((proj_01-proj_10)**2 + (proj_01-proj_11)**2 + (proj_10-proj_11)**2)/3
        elif label_list[j] == 1:
            cost += proj_01 + ((proj_00-proj_10)**2 + (proj_00-proj_11)**2 + (proj_10-proj_11)**2)/3
        elif label_list[j] == 2:
            cost += proj_10 + ((proj_00-proj_01)**2 + (proj_00-proj_11)**2 + (proj_01-proj_11)**2)/3
        else:
            cost += proj_11 + ((proj_00-proj_01)**2 + (proj_00-proj_10)**2 + (proj_01-proj_10)**2)/3
        """

    return cost/num_data

# %%
def accuracy(params):
    accuracy_data = 0
    circuit = cnn(params)
    
    for j in range(num_data):
        final_state = circuit(gs_list[j]).state()

        z3 = np.real(ham3.expectation(final_state))
        z7 = np.real(ham7.expectation(final_state))
        zz37 = np.real(ham37.expectation(final_state))
        
        proj_00 = (1+zz37+z3+z7)/4
        proj_01 = (1-zz37-z3+z7)/4
        proj_10 = (1-zz37+z3-z7)/4
        proj_11 = (1+zz37-z3-z7)/4
        
        if label_list[j] == 0:
            if proj_00 < proj_01 and proj_00 < proj_10 and proj_00 < proj_11:
                accuracy_data += 1
        elif label_list[j] == 1:
            if proj_01 < proj_00 and proj_01 < proj_10 and proj_01 < proj_11:
                accuracy_data += 1
        elif label_list[j] == 2:
            if proj_10 < proj_00 and proj_10 < proj_01 and proj_10 < proj_11:
                accuracy_data += 1
        else:
            if proj_11 < proj_00 and proj_11 < proj_01 and proj_11 < proj_10:
                accuracy_data += 1
            
    return accuracy_data*100/num_data

# %% [markdown]
# # Training

# %%
acc = 0
while acc < accuracy_training:
    initial_params = np.random.uniform(0, 2*np.pi, nparams)
    xopt = cma.fmin2(loss, initial_params, 0.7, options={'tolfun': 0.5e-3})
    print(xopt[1].result.fbest)
    print(xopt[1].result.xbest)
    
    np.savetxt(f"Results\\BEST_PARAMS_j1j2_{num_data}", [xopt[1].result.xbest], newline='')

    acc = accuracy(xopt[1].result.xbest)
    print(acc)
# Out:
# (6_w,12)-aCMA-ES (mu_w=3.7,w_1=40%) in dimension 15 (seed=203625, Wed Dec 20 09:57:53 2023)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     12 1.371307752117835e-01 1.0e+00 6.64e-01  7e-01  7e-01 0:00.0
#     2     24 1.325080089439883e-01 1.1e+00 6.41e-01  6e-01  7e-01 0:00.1
#     3     36 9.862341438811351e-02 1.2e+00 6.30e-01  6e-01  7e-01 0:00.1
#    89   1068 8.204549655494454e-02 5.0e+00 4.38e-02  2e-02  5e-02 0:03.1
#    91   1092 8.205307340593668e-02 5.3e+00 4.38e-02  2e-02  5e-02 0:03.2
# termination on tolfun=0.0005 (Wed Dec 20 09:57:57 2023)
# final/bestever f-value = 8.204860e-02 8.204550e-02 after 1093/1057 evaluations
# incumbent solution: [0.06442296 3.40389136 5.87309442 3.10131909 5.67290122 2.63476213
#  6.39136739 0.88840376 ...]
# std deviations: [0.0290045  0.04013563 0.04916279 0.02397406 0.04696525 0.0462783
#  0.05203237 0.02705282 ...]
# 0.08204549655494454
# [0.02542942 3.39793682 5.87285203 3.12499831 5.71016628 2.68789808
#  6.3881832  0.87279071 0.6485299  6.52692055 1.84451117 3.03717124
#  3.38546474 6.25980624 1.31051792]
# 73.33333333333333
# (6_w,12)-aCMA-ES (mu_w=3.7,w_1=40%) in dimension 15 (seed=83577, Wed Dec 20 09:57:57 2023)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     12 1.516310389048778e-01 1.0e+00 6.47e-01  6e-01  7e-01 0:00.0
#     2     24 1.365239626967505e-01 1.1e+00 6.17e-01  6e-01  6e-01 0:00.1
#     3     36 9.937883758148615e-02 1.2e+00 6.29e-01  6e-01  6e-01 0:00.1
#    85   1020 1.091548777015413e-01 4.0e+00 2.54e+00  2e+00  4e+00 0:03.1
#   100   1200 1.326353459353153e-01 4.5e+00 1.82e+00  1e+00  3e+00 0:03.6
#   200   2400 8.783104077860546e-02 5.9e+00 3.69e-01  2e-01  5e-01 0:07.0
#   294   3528 8.204873336542977e-02 1.1e+01 3.99e-02  9e-03  5e-02 0:10.1
# termination on tolfun=0.0005 (Wed Dec 20 09:58:07 2023)
# final/bestever f-value = 8.204143e-02 7.310254e-02 after 3529/1417 evaluations
# incumbent solution: [-0.02701415 16.27588079 -1.13721724 -9.33102267  5.98864418  9.70095987
# termination on tolfun=0.0005 (Wed Dec 20 09:59:21 2023)
# final/bestever f-value = 2.401200e-02 2.401200e-02 after 1681/1681 evaluations
# incumbent solution: [ 6.98855320e-01  7.38460327e+00  5.46181863e+00  1.08245282e+00
#   5.22953829e+00  4.30048604e+00 -1.14423188e-03  6.37657973e-01 ...]
# std deviations: [0.00481697 0.00590179 0.00580117 0.00491819 0.00527112 0.00619803
#  0.00339675 0.002554   ...]
# 0.024012002092404856
# [ 6.98855320e-01  7.38460327e+00  5.46181863e+00  1.08245282e+00
#   5.22953829e+00  4.30048604e+00 -1.14423188e-03  6.37657973e-01
#   4.71459227e+00  3.89739650e+00  5.93970082e+00 -3.07377055e-01
#   1.36146523e+00 -1.60655140e+00  1.68387333e+00]
# 46.666666666666664
# (6_w,12)-aCMA-ES (mu_w=3.7,w_1=40%) in dimension 15 (seed=189744, Wed Dec 20 09:59:21 2023)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     12 1.129146624177813e-01 1.0e+00 6.59e-01  6e-01  7e-01 0:00.0
#     2     24 1.215437459755734e-01 1.1e+00 6.30e-01  6e-01  6e-01 0:00.1
#     3     36 1.350548534357752e-01 1.1e+00 6.03e-01  6e-01  6e-01 0:00.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 4
#       2 while acc < accuracy_training:
#       3     initial_params = np.random.uniform(0, 2*np.pi, nparams)
# ----> 4     xopt = cma.fmin2(loss, initial_params, 0.7, options={'tolfun': 0.5e-3})
#       5     print(xopt[1].result.fbest)
#       6     print(xopt[1].result.xbest)
#
# File d:\Documents\1. GitHub\venv\lib\site-packages\cma\evolution_strategy.py:4392, in fmin2(objective_function, x0, sigma0, options, args, gradf, restarts, restart_from_best, incpopsize, eval_initial_x, parallel_objective, noise_handler, noise_change_sigma_exponent, noise_kappa_exponent, bipop, callback)
#    4344 def fmin2(objective_function, x0, sigma0,
#    4345          options=None,
#    4346          args=(),
#    (...)
#    4356          bipop=False,
#    4357          callback=None):
#    4358     """wrapper around `cma.fmin` returning the tuple ``(xbest, es)``,
#    4359
#    4360     and with the same in input arguments as `fmin`. Hence a typical
#    (...)
#    4390
#    4391     """
# -> 4392     res = fmin(objective_function, x0, sigma0,
#    4393          options,
#    4394          args,
#    4395          gradf,
#    4396          restarts,
#    4397          restart_from_best,
#    4398          incpopsize,
#    4399          eval_initial_x,
#    4400          parallel_objective,
#    4401          noise_handler,
#    4402          noise_change_sigma_exponent,
#    4403          noise_kappa_exponent,
#    4404          bipop,
#    4405          callback)
#    4406     return res[0], res[-2]
#
# File d:\Documents\1. GitHub\venv\lib\site-packages\cma\evolution_strategy.py:4818, in fmin(objective_function, x0, sigma0, options, args, gradf, restarts, restart_from_best, incpopsize, eval_initial_x, parallel_objective, noise_handler, noise_change_sigma_exponent, noise_kappa_exponent, bipop, callback)
#    4815 if 1 < 3:
#    4816     while not es.stop():  # iteration loop
#    4817         # X, fit = eval_in_parallel(lambda: es.ask(1)[0], es.popsize, args, repetitions=noisehandler.evaluations-1)
# -> 4818         X, fit = es.ask_and_eval(parallel_objective or objective_function,
#    4819                                  args, gradf=gradf,
#    4820                                  evaluations=noisehandler.evaluations,
#    4821                                  aggregation=np.median,
#    4822                                  parallel_mode=parallel_objective)  # treats NaN with resampling if not parallel_mode
#    4823         # TODO: check args and in case use args=(noisehandler.evaluations, )
#    4825         if 11 < 3 and opts['vv']:  # inject a solution
#    4826             # use option check_point = [0]
#
# File d:\Documents\1. GitHub\venv\lib\site-packages\cma\evolution_strategy.py:2528, in CMAEvolutionStrategy.ask_and_eval(self, func, args, gradf, number, xmean, sigma_fac, evaluations, aggregation, kappa, parallel_mode)
#    2524     length_normalizer = self.N**0.5 / self.mahalanobis_norm(x - xmean)  # self.const.chiN < N**0.5, the constant here is irrelevant (absorbed by kappa)
#    2525     # print(self.N**0.5 / self.mahalanobis_norm(x - xmean))
#    2526     # self.more_to_write += [length_normalizer * 1e-3, length_normalizer * self.mahalanobis_norm(x - xmean) * 1e2]
# -> 2528 f = func(x, *args) if kappa == 1 else \
#    2529     func(xmean + kappa * length_normalizer * (x - xmean),
#    2530          *args)
#    2531 if is_feasible(x, f) and evaluations > 1:
#    2532     f = aggregation([f] + [(func(x, *args) if kappa == 1 else
#    2533                             func(xmean + kappa * length_normalizer * (x - xmean), *args))
#    2534                            for _i in range(int(evaluations - 1))])
#
# Cell In[11], line 8, in loss(params)
#       5 for j in range(num_data):
#       6     final_state = circuit(gs_list[j]).state()
# ----> 8     z3 = np.real(ham3.expectation(final_state))
#       9     z7 = np.real(ham7.expectation(final_state))
#      10     zz37 = np.real(ham37.expectation(final_state))
#
# File d:\Documents\1. GitHub\venv\lib\site-packages\qibo\hamiltonians\hamiltonians.py:554, in SymbolicHamiltonian.expectation(self, state, normalize)
#     553 def expectation(self, state, normalize=False):
# --> 554     return Hamiltonian.expectation(self, state, normalize)
#
# File d:\Documents\1. GitHub\venv\lib\site-packages\qibo\hamiltonians\hamiltonians.py:124, in Hamiltonian.expectation(self, state, normalize)
#     122 shape = tuple(state.shape)
#     123 if len(shape) == 1:  # state vector
# --> 124     return self.backend.calculate_expectation_state(self, state, normalize)
#     126 if len(shape) == 2:  # density matrix
#     127     return self.backend.calculate_expectation_density_matrix(
#     128         self, state, normalize
#     129     )
#
# File d:\Documents\1. GitHub\venv\lib\site-packages\qibo\backends\numpy.py:747, in NumpyBackend.calculate_expectation_state(self, hamiltonian, state, normalize)
#     745 def calculate_expectation_state(self, hamiltonian, state, normalize):
#     746     statec = self.np.conj(state)
# --> 747     hstate = hamiltonian @ state
#     748     ev = self.np.real(self.np.sum(statec * hstate))
#     749     if normalize:
#
# File d:\Documents\1. GitHub\venv\lib\site-packages\qibo\hamiltonians\hamiltonians.py:753, in SymbolicHamiltonian.__matmul__(self, o)
#     747         raise_error(
#     748             ValueError,
#     749             f"Cannot multiply Hamiltonian on {self.nqubits} qubits to "
#     750             + f"state of {state_qubits} qubits.",
#     751         )
#     752     if rank == 1:  # state vector
# --> 753         return self.apply_gates(o)
#     755     return self.apply_gates(o, density_matrix=True)
#     757 raise_error(
#     758     NotImplementedError,
#     759     f"Hamiltonian matmul to {type(o)} not implemented.",
#     760 )
#
# File d:\Documents\1. GitHub\venv\lib\site-packages\qibo\hamiltonians\hamiltonians.py:711, in SymbolicHamiltonian.apply_gates(self, state, density_matrix)
#     707 total = 0
#     708 for term in self.terms:
#     709     total += term(
#     710         self.backend,
# --> 711         self.backend.cast(state, copy=True),
#     712         self.nqubits,
#     713         density_matrix=density_matrix,
#     714     )
#     715 if self.constant:  # pragma: no cover
#     716     total += self.constant * state
#
# File d:\Documents\1. GitHub\venv\lib\site-packages\qibo\backends\numpy.py:60, in NumpyBackend.cast(self, x, dtype, copy)
#      58     dtype = self.dtype
#      59 if isinstance(x, self.tensor_types):
# ---> 60     return x.astype(dtype, copy=copy)
#      61 elif self.issparse(x):
#      62     return x.astype(dtype, copy=copy)
#
# KeyboardInterrupt:
